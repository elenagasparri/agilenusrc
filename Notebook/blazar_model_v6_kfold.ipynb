# %% [markdown]
# # Bi-Directional LSTM neural network trained whit K-Fold Cross Validation

# %% [markdown]
# * Impostazione per uso della GPU

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from tensorflow import keras
from keras import layers
print("TensorFlow version:", tf.__version__)

import numpy as np
print('Numpy version:', np.__version__)

from matplotlib import pyplot as plt
# Out:
# TensorFlow version: 2.8.0
# Numpy version: 1.21.6

# %%
cd drive/MyDrive/Colab\ Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %ls
# Out:
#  2LS/                                  media.ipynb
#  BlazarDNN.ipynb                       model.png
#  BlazarDNN_vecchio.ipynb               model_v2/
#  blazar_model_colab.ipynb              model_v3/
#  blazar_model_colab_v2.ipynb           model_v4/
#  blazar_model_colab_v3.ipynb           model_v5/
#  blazar_model_colab_v5.ipynb           model_v6/
#  blazar_model_colab_v6.ipynb           model_v6_nokfold/
#  blazar_model_colab_v6_nokfold.ipynb   model_voub/
#  blazar_model_colab_v7_plot.ipynb      newfile.txt
# 'Copia di KerasSimple.ipynb'           nn_data.npz
# 'Copy of CNN tutorial.ipynb'           nn_data_v2.npz
# 'Copy of Jet_exploration.ipynb'        nn_data_v3.npz
#  example_txs0506+056.ipynb             nn_data_voub.npz
#  k_model_pot.py                        __pycache__/
# 'Lezione GPU.ipynb'                    TXS0506056.txt
#  Librerie.ipynb

# %% [markdown]
# * Final preprocessing dei dati

# %%
# nn_data.npz archivio con i 2 np.ndarray 'bl_data' (4627, 529, 2) 'agn_data' (4059, 529, 2) e  np.array 'nn_freq_data' (529,)
# nn_data.npz ha i flag nei dati sed a 1 per blazars e a 0 per agn
# nn_data_v2.npz ha i flag a 1 per blazar e agn dove abbiamo misura vera del flusso
#                i label per distinguere tra blazar e agn da costruire a parte
# nn_data_v3.npz è corretto rispetto a *_v2.npz: non ha i nan, non ha flussi negativi e non ha flussi superiori a 10^-5
#nn_data = np.load('nn_data_voub.npz')
nn_data = np.load('nn_data_v3.npz')

bl_data = nn_data['bl_data']
agn_data = nn_data['agn_data']
set_freq = nn_data['nn_freq_data']

# %%
print(bl_data.shape)
print(agn_data.shape)
# Out:
# (4627, 529, 2)
# (4059, 529, 2)

# %%
# Verifica che non ci siano valori NAN inaspettati nelle misure di flusso
with np.printoptions(threshold=np.inf):
  nanbl_idx=np.argwhere(np.isnan(bl_data))
  nanagn_idx=np.argwhere(np.isnan(agn_data))
  print('Indici delle sed blazar con NAN: ',nanbl_idx)
  print('Indici delle sed agn con NAN: ',nanagn_idx)
# Out:
# Indici delle sed blazar con NAN:  []
# Indici delle sed agn con NAN:  []

# %%
# Dati pronti per essere concatenati

data = np.concatenate((bl_data, agn_data), axis =0)
print(data.shape)
# Out:
# (8686, 529, 2)

# %% [markdown]
# Adesso posso riscalare i miei valori di flusso tra 0 e 1

# %%
# funzione per normalizzare dati
ptp=np.ptp(data[:,:,0])
min = np.min(data[:,:,0])
max = np.max(data[:,:,0])
print(min)
print(max)
print(ptp)
data[:,:,0]= (data[:,:,0]-min)/ptp
# Out:
# 0.0
# 1.0121e-08
# 1.0121e-08

# %%
# Creo le label
label = np.concatenate((np.ones(bl_data.shape[0]),np.zeros(agn_data.shape[0])))

# %%
label.shape
# Out:
# (8686,)

# %%
bl_data = data[0:4626]
agn_data = data[4627:]
bl_label = label[0:4626]
agn_label = label[4627:]

# %%
from sklearn.model_selection import train_test_split

data_train_bl, data_test_bl, l_train_bl, l_test_bl = train_test_split(bl_data, bl_label, test_size=0.1, random_state=1)
data_train_agn, data_test_agn, l_train_agn, l_test_agn = train_test_split(agn_data, agn_label, test_size=0.1, random_state=1)

# %%
len(data_train_bl)
# Out:
# 4163

# %%
len(data_train_agn)
# Out:
# 3653

# %%
data_train_bl_tmp = data_train_bl[0:3652]
l_train_bl_tmp = l_train_bl[0:3652]

# %%
data = np.concatenate((data_train_bl_tmp,data_train_agn))
data_test_bl = np.concatenate((data_test_bl, data_train_bl[3653:]))
l_test_bl = np.concatenate((l_test_bl,l_train_bl[3653:]))
l_train_bl = l_train_bl_tmp

# %%
label = np.concatenate((l_train_bl, l_train_agn))

# %%
# Permuto il train dataset
permutation = np.random.permutation(data.shape[0])
data_train=data[permutation]
l_train=label[permutation]

# %%
l_test=np.concatenate((l_test_bl,l_test_agn))
data_test=np.concatenate((data_test_bl,data_test_agn))

# %%
# Definisco le dimensione dell'array di Input
ishape=data.shape[1:]
ishape
# Out:
# (529, 2)

# %%
init = tf.keras.initializers.LecunNormal(5)

model = keras.Sequential()
model.add(keras.Input(shape = ishape)) # input
model.add(keras.layers.Conv1D(filters = 128,kernel_initializer=init, kernel_size = 3, strides=1, padding='same',
    activation=None))
model.add(layers.Activation('tanh'))
model.add(keras.layers.MaxPool1D(pool_size=2, strides=2, padding='valid'))
model.add(keras.layers.Conv1D(filters = 256,kernel_initializer=init, kernel_size = 3, strides=1, padding='same',
    activation=None))
model.add(layers.Activation('tanh'))
model.add(keras.layers.MaxPool1D(pool_size=2, strides=2, padding='valid'))
model.add(keras.layers.Conv1D(filters = 512,kernel_initializer=init, kernel_size = 3, strides=1, padding='same',
    activation=None))
model.add(layers.Activation('tanh'))
model.add(keras.layers.MaxPool1D(pool_size=2, strides=2, padding='valid'))
model.add(keras.layers.Bidirectional(keras.layers.LSTM(1024)))
model.add(keras.layers.Dense(512, activation='relu',kernel_initializer=init, use_bias=True))
model.add(keras.layers.Dropout(0.6))
model.add(keras.layers.Dense(256, activation='relu', kernel_initializer=init, use_bias=True))
model.add(keras.layers.Dropout(0.4))
model.add(keras.layers.Dense(1, activation='relu', kernel_initializer=init, use_bias=True))

opt = tf.keras.optimizers.Adadelta(learning_rate=0.001)

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary() # stampa modello riga per riga
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 529, 128)          896
#
#  activation (Activation)     (None, 529, 128)          0
#
#  max_pooling1d (MaxPooling1D  (None, 264, 128)         0
#  )
#
#  conv1d_1 (Conv1D)           (None, 264, 256)          98560
#
#  activation_1 (Activation)   (None, 264, 256)          0
#
#  max_pooling1d_1 (MaxPooling  (None, 132, 256)         0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 132, 512)          393728
#
#  activation_2 (Activation)   (None, 132, 512)          0
#
#  max_pooling1d_2 (MaxPooling  (None, 66, 512)          0
#  1D)
#
#  bidirectional (Bidirectiona  (None, 2048)             12591104
#  l)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 14,264,961
# Trainable params: 14,264,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
#from keras.utils import plot_model

keras.utils.plot_model(model, to_file ='model.png',show_shapes=True,rankdir='LR')

# %%
# split of train dataset in 9 fold: 8 for training, 1 for validation
from sklearn.model_selection import KFold

kf = KFold(n_splits=9, shuffle = True, random_state = 1)

# %%
def get_model_name(k):
    return 'model_'+str(k)+'.h5'

save_dir = 'model_v6/'
fold_var = 0
history_list = []
for train_idx, val_idx in kf.split(data_train):
  fold_var = fold_var+1
  print(train_idx.shape, val_idx.shape)
  # CREATE CALLBACKS
  checkpoint = tf.keras.callbacks.ModelCheckpoint(save_dir+get_model_name(fold_var), 
							monitor='val_accuracy', verbose=1, 
							save_best_only=True, mode='max')
  earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=4)
  callbacks_list = [checkpoint,earlystopping]
  history=model.fit(x=data_train[train_idx],y=l_train[train_idx],validation_data=(data_train[val_idx],l_train[val_idx]),epochs=20, callbacks=callbacks_list)
  np.save(f'model_v6/my_history_{fold_var}.npy',history.history)
  history_list.append(history)
# Out:
# (6493,) (812,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 2.5067 - accuracy: 0.4988
# Epoch 1: val_accuracy improved from -inf to 0.50985, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 66s 250ms/step - loss: 2.5067 - accuracy: 0.4988 - val_loss: 1.8483 - val_accuracy: 0.5099
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 1.9331 - accuracy: 0.4988
# Epoch 2: val_accuracy did not improve from 0.50985
# 203/203 [==============================] - 41s 203ms/step - loss: 1.9331 - accuracy: 0.4988 - val_loss: 1.6010 - val_accuracy: 0.5099
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 1.5687 - accuracy: 0.4988
# Epoch 3: val_accuracy did not improve from 0.50985
# 203/203 [==============================] - 41s 202ms/step - loss: 1.5687 - accuracy: 0.4988 - val_loss: 1.3875 - val_accuracy: 0.5099
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 1.3349 - accuracy: 0.4990
# Epoch 4: val_accuracy did not improve from 0.50985
# 203/203 [==============================] - 41s 202ms/step - loss: 1.3349 - accuracy: 0.4990 - val_loss: 1.1319 - val_accuracy: 0.5099
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 1.0539 - accuracy: 0.5018
# Epoch 5: val_accuracy improved from 0.50985 to 0.51478, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 210ms/step - loss: 1.0539 - accuracy: 0.5018 - val_loss: 0.8734 - val_accuracy: 0.5148
# Epoch 6/20
# 203/203 [==============================] - ETA: 0s - loss: 0.8404 - accuracy: 0.5264
# Epoch 6: val_accuracy improved from 0.51478 to 0.54310, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.8404 - accuracy: 0.5264 - val_loss: 0.7607 - val_accuracy: 0.5431
# Epoch 7/20
# 203/203 [==============================] - ETA: 0s - loss: 0.8006 - accuracy: 0.5537
# Epoch 7: val_accuracy improved from 0.54310 to 0.54926, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.8006 - accuracy: 0.5537 - val_loss: 0.7362 - val_accuracy: 0.5493
# Epoch 8/20
# 203/203 [==============================] - ETA: 0s - loss: 0.8052 - accuracy: 0.5715
# Epoch 8: val_accuracy improved from 0.54926 to 0.57389, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 210ms/step - loss: 0.8052 - accuracy: 0.5715 - val_loss: 0.7562 - val_accuracy: 0.5739
# Epoch 9/20
# 203/203 [==============================] - ETA: 0s - loss: 0.8105 - accuracy: 0.5797
# Epoch 9: val_accuracy improved from 0.57389 to 0.57512, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 210ms/step - loss: 0.8105 - accuracy: 0.5797 - val_loss: 0.7367 - val_accuracy: 0.5751
# Epoch 10/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7907 - accuracy: 0.5771
# Epoch 10: val_accuracy improved from 0.57512 to 0.57759, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 210ms/step - loss: 0.7907 - accuracy: 0.5771 - val_loss: 0.7220 - val_accuracy: 0.5776
# Epoch 11/20
# 203/203 [==============================] - ETA: 0s - loss: 0.8173 - accuracy: 0.5802
# Epoch 11: val_accuracy improved from 0.57759 to 0.58005, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 210ms/step - loss: 0.8173 - accuracy: 0.5802 - val_loss: 0.7154 - val_accuracy: 0.5800
# Epoch 12/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7899 - accuracy: 0.5802
# Epoch 12: val_accuracy improved from 0.58005 to 0.58374, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 210ms/step - loss: 0.7899 - accuracy: 0.5802 - val_loss: 0.7106 - val_accuracy: 0.5837
# Epoch 13/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7709 - accuracy: 0.5814
# Epoch 13: val_accuracy improved from 0.58374 to 0.58498, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.7709 - accuracy: 0.5814 - val_loss: 0.7055 - val_accuracy: 0.5850
# Epoch 14/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7812 - accuracy: 0.5856
# Epoch 14: val_accuracy improved from 0.58498 to 0.58744, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.7812 - accuracy: 0.5856 - val_loss: 0.7037 - val_accuracy: 0.5874
# Epoch 15/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7761 - accuracy: 0.5806
# Epoch 15: val_accuracy improved from 0.58744 to 0.58990, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.7761 - accuracy: 0.5806 - val_loss: 0.7010 - val_accuracy: 0.5899
# Epoch 16/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7521 - accuracy: 0.5868
# Epoch 16: val_accuracy did not improve from 0.58990
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7521 - accuracy: 0.5868 - val_loss: 0.6994 - val_accuracy: 0.5887
# Epoch 17/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7591 - accuracy: 0.5771
# Epoch 17: val_accuracy improved from 0.58990 to 0.59113, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.7591 - accuracy: 0.5771 - val_loss: 0.6977 - val_accuracy: 0.5911
# Epoch 18/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7489 - accuracy: 0.5871
# Epoch 18: val_accuracy did not improve from 0.59113
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7489 - accuracy: 0.5871 - val_loss: 0.6955 - val_accuracy: 0.5874
# Epoch 19/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7364 - accuracy: 0.5811
# Epoch 19: val_accuracy improved from 0.59113 to 0.59606, saving model to model_v6/model_1.h5
# 203/203 [==============================] - 43s 214ms/step - loss: 0.7364 - accuracy: 0.5811 - val_loss: 0.6932 - val_accuracy: 0.5961
# Epoch 20/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.5839
# Epoch 20: val_accuracy did not improve from 0.59606
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7443 - accuracy: 0.5839 - val_loss: 0.6910 - val_accuracy: 0.5948
# (6493,) (812,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7368 - accuracy: 0.5837
# Epoch 1: val_accuracy improved from -inf to 0.60345, saving model to model_v6/model_2.h5
# 203/203 [==============================] - 44s 216ms/step - loss: 0.7368 - accuracy: 0.5837 - val_loss: 0.6777 - val_accuracy: 0.6034
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7431 - accuracy: 0.5896
# Epoch 2: val_accuracy improved from 0.60345 to 0.60714, saving model to model_v6/model_2.h5
# 203/203 [==============================] - 43s 212ms/step - loss: 0.7431 - accuracy: 0.5896 - val_loss: 0.6752 - val_accuracy: 0.6071
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7464 - accuracy: 0.5883
# Epoch 3: val_accuracy did not improve from 0.60714
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7464 - accuracy: 0.5883 - val_loss: 0.6726 - val_accuracy: 0.6059
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7230 - accuracy: 0.5857
# Epoch 4: val_accuracy improved from 0.60714 to 0.60961, saving model to model_v6/model_2.h5
# 203/203 [==============================] - 43s 212ms/step - loss: 0.7230 - accuracy: 0.5857 - val_loss: 0.6739 - val_accuracy: 0.6096
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7245 - accuracy: 0.5894
# Epoch 5: val_accuracy did not improve from 0.60961
# 203/203 [==============================] - 41s 202ms/step - loss: 0.7245 - accuracy: 0.5894 - val_loss: 0.6719 - val_accuracy: 0.6084
# Epoch 6/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7327 - accuracy: 0.5859
# Epoch 6: val_accuracy did not improve from 0.60961
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7327 - accuracy: 0.5859 - val_loss: 0.6714 - val_accuracy: 0.6084
# Epoch 7/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7051 - accuracy: 0.5977
# Epoch 7: val_accuracy did not improve from 0.60961
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7051 - accuracy: 0.5977 - val_loss: 0.6703 - val_accuracy: 0.6084
# Epoch 8/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7220 - accuracy: 0.5897
# Epoch 8: val_accuracy did not improve from 0.60961
# 203/203 [==============================] - 42s 206ms/step - loss: 0.7220 - accuracy: 0.5897 - val_loss: 0.6677 - val_accuracy: 0.6071
# (6493,) (812,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7188 - accuracy: 0.5869
# Epoch 1: val_accuracy improved from -inf to 0.65764, saving model to model_v6/model_3.h5
# 203/203 [==============================] - 44s 216ms/step - loss: 0.7188 - accuracy: 0.5869 - val_loss: 0.6475 - val_accuracy: 0.6576
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7160 - accuracy: 0.5837
# Epoch 2: val_accuracy did not improve from 0.65764
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7160 - accuracy: 0.5837 - val_loss: 0.6468 - val_accuracy: 0.6552
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7078 - accuracy: 0.5869
# Epoch 3: val_accuracy did not improve from 0.65764
# 203/203 [==============================] - 41s 202ms/step - loss: 0.7078 - accuracy: 0.5869 - val_loss: 0.6461 - val_accuracy: 0.6527
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7154 - accuracy: 0.5831
# Epoch 4: val_accuracy did not improve from 0.65764
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7154 - accuracy: 0.5831 - val_loss: 0.6453 - val_accuracy: 0.6502
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7199 - accuracy: 0.5828
# Epoch 5: val_accuracy did not improve from 0.65764
# 203/203 [==============================] - 41s 202ms/step - loss: 0.7199 - accuracy: 0.5828 - val_loss: 0.6448 - val_accuracy: 0.6515
# (6493,) (812,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7255 - accuracy: 0.5902
# Epoch 1: val_accuracy improved from -inf to 0.62069, saving model to model_v6/model_4.h5
# 203/203 [==============================] - 43s 212ms/step - loss: 0.7255 - accuracy: 0.5902 - val_loss: 0.6601 - val_accuracy: 0.6207
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7030 - accuracy: 0.5949
# Epoch 2: val_accuracy improved from 0.62069 to 0.62685, saving model to model_v6/model_4.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.7030 - accuracy: 0.5949 - val_loss: 0.6594 - val_accuracy: 0.6268
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.5956
# Epoch 3: val_accuracy did not improve from 0.62685
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6939 - accuracy: 0.5956 - val_loss: 0.6594 - val_accuracy: 0.6256
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6964 - accuracy: 0.5906
# Epoch 4: val_accuracy did not improve from 0.62685
# 203/203 [==============================] - 42s 206ms/step - loss: 0.6964 - accuracy: 0.5906 - val_loss: 0.6592 - val_accuracy: 0.6256
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7009 - accuracy: 0.5949
# Epoch 5: val_accuracy did not improve from 0.62685
# 203/203 [==============================] - 41s 203ms/step - loss: 0.7009 - accuracy: 0.5949 - val_loss: 0.6590 - val_accuracy: 0.6268
# Epoch 6/20
# 203/203 [==============================] - ETA: 0s - loss: 0.7045 - accuracy: 0.5905
# Epoch 6: val_accuracy improved from 0.62685 to 0.62931, saving model to model_v6/model_4.h5
# 203/203 [==============================] - 43s 214ms/step - loss: 0.7045 - accuracy: 0.5905 - val_loss: 0.6580 - val_accuracy: 0.6293
# Epoch 7/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.5994
# Epoch 7: val_accuracy improved from 0.62931 to 0.63300, saving model to model_v6/model_4.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.6906 - accuracy: 0.5994 - val_loss: 0.6569 - val_accuracy: 0.6330
# Epoch 8/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.5920
# Epoch 8: val_accuracy improved from 0.63300 to 0.63424, saving model to model_v6/model_4.h5
# 203/203 [==============================] - 43s 214ms/step - loss: 0.6965 - accuracy: 0.5920 - val_loss: 0.6567 - val_accuracy: 0.6342
# Epoch 9/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.6068
# Epoch 9: val_accuracy did not improve from 0.63424
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6924 - accuracy: 0.6068 - val_loss: 0.6569 - val_accuracy: 0.6342
# Epoch 10/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0.5933
# Epoch 10: val_accuracy improved from 0.63424 to 0.63547, saving model to model_v6/model_4.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.6913 - accuracy: 0.5933 - val_loss: 0.6565 - val_accuracy: 0.6355
# Epoch 11/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.5909
# Epoch 11: val_accuracy did not improve from 0.63547
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6940 - accuracy: 0.5909 - val_loss: 0.6568 - val_accuracy: 0.6305
# Epoch 12/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.5871
# Epoch 12: val_accuracy did not improve from 0.63547
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6962 - accuracy: 0.5871 - val_loss: 0.6575 - val_accuracy: 0.6268
# Epoch 13/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6910 - accuracy: 0.5974
# Epoch 13: val_accuracy improved from 0.63547 to 0.63793, saving model to model_v6/model_4.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.6910 - accuracy: 0.5974 - val_loss: 0.6542 - val_accuracy: 0.6379
# Epoch 14/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6981 - accuracy: 0.5973
# Epoch 14: val_accuracy did not improve from 0.63793
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6981 - accuracy: 0.5973 - val_loss: 0.6558 - val_accuracy: 0.6330
# Epoch 15/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6860 - accuracy: 0.5951
# Epoch 15: val_accuracy did not improve from 0.63793
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6860 - accuracy: 0.5951 - val_loss: 0.6562 - val_accuracy: 0.6342
# Epoch 16/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6834 - accuracy: 0.5934
# Epoch 16: val_accuracy did not improve from 0.63793
# 203/203 [==============================] - 41s 202ms/step - loss: 0.6834 - accuracy: 0.5934 - val_loss: 0.6541 - val_accuracy: 0.6379
# Epoch 17/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6806 - accuracy: 0.5983
# Epoch 17: val_accuracy did not improve from 0.63793
# 203/203 [==============================] - 41s 202ms/step - loss: 0.6806 - accuracy: 0.5983 - val_loss: 0.6549 - val_accuracy: 0.6355
# (6493,) (812,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6888 - accuracy: 0.5905
# Epoch 1: val_accuracy improved from -inf to 0.66379, saving model to model_v6/model_5.h5
# 203/203 [==============================] - 44s 215ms/step - loss: 0.6888 - accuracy: 0.5905 - val_loss: 0.6463 - val_accuracy: 0.6638
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6902 - accuracy: 0.5916
# Epoch 2: val_accuracy improved from 0.66379 to 0.66626, saving model to model_v6/model_5.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.6902 - accuracy: 0.5916 - val_loss: 0.6453 - val_accuracy: 0.6663
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.5968
# Epoch 3: val_accuracy did not improve from 0.66626
# 203/203 [==============================] - 41s 202ms/step - loss: 0.6852 - accuracy: 0.5968 - val_loss: 0.6453 - val_accuracy: 0.6638
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6833 - accuracy: 0.5911
# Epoch 4: val_accuracy did not improve from 0.66626
# 203/203 [==============================] - 41s 202ms/step - loss: 0.6833 - accuracy: 0.5911 - val_loss: 0.6464 - val_accuracy: 0.6626
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6809 - accuracy: 0.6025
# Epoch 5: val_accuracy did not improve from 0.66626
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6809 - accuracy: 0.6025 - val_loss: 0.6462 - val_accuracy: 0.6638
# Epoch 6/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6836 - accuracy: 0.5982
# Epoch 6: val_accuracy did not improve from 0.66626
# 203/203 [==============================] - 41s 202ms/step - loss: 0.6836 - accuracy: 0.5982 - val_loss: 0.6446 - val_accuracy: 0.6638
# (6493,) (812,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6851 - accuracy: 0.6000
# Epoch 1: val_accuracy improved from -inf to 0.64532, saving model to model_v6/model_6.h5
# 203/203 [==============================] - 43s 212ms/step - loss: 0.6851 - accuracy: 0.6000 - val_loss: 0.6570 - val_accuracy: 0.6453
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.5973
# Epoch 2: val_accuracy improved from 0.64532 to 0.64655, saving model to model_v6/model_6.h5
# 203/203 [==============================] - 43s 210ms/step - loss: 0.6900 - accuracy: 0.5973 - val_loss: 0.6572 - val_accuracy: 0.6466
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6769 - accuracy: 0.6062
# Epoch 3: val_accuracy did not improve from 0.64655
# 203/203 [==============================] - 41s 202ms/step - loss: 0.6769 - accuracy: 0.6062 - val_loss: 0.6565 - val_accuracy: 0.6441
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6893 - accuracy: 0.5985
# Epoch 4: val_accuracy did not improve from 0.64655
# 203/203 [==============================] - 41s 202ms/step - loss: 0.6893 - accuracy: 0.5985 - val_loss: 0.6565 - val_accuracy: 0.6441
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6811 - accuracy: 0.5968
# Epoch 5: val_accuracy did not improve from 0.64655
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6811 - accuracy: 0.5968 - val_loss: 0.6567 - val_accuracy: 0.6453
# Epoch 6/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6850 - accuracy: 0.6023
# Epoch 6: val_accuracy did not improve from 0.64655
# 203/203 [==============================] - 41s 202ms/step - loss: 0.6850 - accuracy: 0.6023 - val_loss: 0.6567 - val_accuracy: 0.6441
# (6494,) (811,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6827 - accuracy: 0.6013
# Epoch 1: val_accuracy improved from -inf to 0.62022, saving model to model_v6/model_7.h5
# 203/203 [==============================] - 43s 213ms/step - loss: 0.6827 - accuracy: 0.6013 - val_loss: 0.6595 - val_accuracy: 0.6202
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6855 - accuracy: 0.5918
# Epoch 2: val_accuracy improved from 0.62022 to 0.62515, saving model to model_v6/model_7.h5
# 203/203 [==============================] - 43s 212ms/step - loss: 0.6855 - accuracy: 0.5918 - val_loss: 0.6576 - val_accuracy: 0.6252
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6842 - accuracy: 0.6030
# Epoch 3: val_accuracy did not improve from 0.62515
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6842 - accuracy: 0.6030 - val_loss: 0.6581 - val_accuracy: 0.6178
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6868 - accuracy: 0.5907
# Epoch 4: val_accuracy did not improve from 0.62515
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6868 - accuracy: 0.5907 - val_loss: 0.6578 - val_accuracy: 0.6178
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6780 - accuracy: 0.6030
# Epoch 5: val_accuracy did not improve from 0.62515
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6780 - accuracy: 0.6030 - val_loss: 0.6572 - val_accuracy: 0.6227
# Epoch 6/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6820 - accuracy: 0.6070
# Epoch 6: val_accuracy did not improve from 0.62515
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6820 - accuracy: 0.6070 - val_loss: 0.6574 - val_accuracy: 0.6215
# (6494,) (811,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6756 - accuracy: 0.6052
# Epoch 1: val_accuracy improved from -inf to 0.61776, saving model to model_v6/model_8.h5
# 203/203 [==============================] - 43s 213ms/step - loss: 0.6756 - accuracy: 0.6052 - val_loss: 0.6639 - val_accuracy: 0.6178
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6800 - accuracy: 0.6049
# Epoch 2: val_accuracy improved from 0.61776 to 0.62146, saving model to model_v6/model_8.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.6800 - accuracy: 0.6049 - val_loss: 0.6640 - val_accuracy: 0.6215
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6770 - accuracy: 0.5952
# Epoch 3: val_accuracy did not improve from 0.62146
# 203/203 [==============================] - 41s 204ms/step - loss: 0.6770 - accuracy: 0.5952 - val_loss: 0.6634 - val_accuracy: 0.6202
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6803 - accuracy: 0.6004
# Epoch 4: val_accuracy did not improve from 0.62146
# 203/203 [==============================] - 41s 204ms/step - loss: 0.6803 - accuracy: 0.6004 - val_loss: 0.6652 - val_accuracy: 0.6079
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6804 - accuracy: 0.5952
# Epoch 5: val_accuracy did not improve from 0.62146
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6804 - accuracy: 0.5952 - val_loss: 0.6642 - val_accuracy: 0.6202
# Epoch 6/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6730 - accuracy: 0.6058
# Epoch 6: val_accuracy improved from 0.62146 to 0.62269, saving model to model_v6/model_8.h5
# 203/203 [==============================] - 43s 211ms/step - loss: 0.6730 - accuracy: 0.6058 - val_loss: 0.6631 - val_accuracy: 0.6227
# Epoch 7/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6769 - accuracy: 0.6044
# Epoch 7: val_accuracy did not improve from 0.62269
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6769 - accuracy: 0.6044 - val_loss: 0.6633 - val_accuracy: 0.6227
# Epoch 8/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6793 - accuracy: 0.6059
# Epoch 8: val_accuracy did not improve from 0.62269
# 203/203 [==============================] - 42s 206ms/step - loss: 0.6793 - accuracy: 0.6059 - val_loss: 0.6641 - val_accuracy: 0.6178
# Epoch 9/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6825 - accuracy: 0.6015
# Epoch 9: val_accuracy did not improve from 0.62269
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6825 - accuracy: 0.6015 - val_loss: 0.6635 - val_accuracy: 0.6202
# Epoch 10/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6780 - accuracy: 0.6110
# Epoch 10: val_accuracy did not improve from 0.62269
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6780 - accuracy: 0.6110 - val_loss: 0.6639 - val_accuracy: 0.6178
# (6494,) (811,)
# Epoch 1/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6819 - accuracy: 0.5996
# Epoch 1: val_accuracy improved from -inf to 0.58940, saving model to model_v6/model_9.h5
# 203/203 [==============================] - 44s 215ms/step - loss: 0.6819 - accuracy: 0.5996 - val_loss: 0.6818 - val_accuracy: 0.5894
# Epoch 2/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6716 - accuracy: 0.6089
# Epoch 2: val_accuracy did not improve from 0.58940
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6716 - accuracy: 0.6089 - val_loss: 0.6816 - val_accuracy: 0.5882
# Epoch 3/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6739 - accuracy: 0.6009
# Epoch 3: val_accuracy did not improve from 0.58940
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6739 - accuracy: 0.6009 - val_loss: 0.6821 - val_accuracy: 0.5869
# Epoch 4/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6731 - accuracy: 0.6090
# Epoch 4: val_accuracy did not improve from 0.58940
# 203/203 [==============================] - 41s 204ms/step - loss: 0.6731 - accuracy: 0.6090 - val_loss: 0.6821 - val_accuracy: 0.5882
# Epoch 5/20
# 203/203 [==============================] - ETA: 0s - loss: 0.6679 - accuracy: 0.6101
# Epoch 5: val_accuracy did not improve from 0.58940
# 203/203 [==============================] - 41s 203ms/step - loss: 0.6679 - accuracy: 0.6101 - val_loss: 0.6817 - val_accuracy: 0.5882

# %%
i = 0
for history in history_list:
  i=i+1
  #print(history.history.keys())
  fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True)
  fig.suptitle(f'Loss and accuracy plot fold_{i}')

  ax1.plot(history.history["val_loss"], label='validation')
  ax1.plot(history.history["loss"], label='training')
  ax1.legend(loc="upper right")
  ax1.set_xlabel('Epochs')
  ax1.set_ylabel('Loss')
  #ax1.set_xlim(-0.5,10)
  #ax1.set_ylim(0.1,0.7)
  
  ax2.plot(history.history["val_accuracy"], label='validation')
  ax2.plot(history.history["accuracy"], label='training')
  ax2.legend(loc="lower right")
  ax2.set_xlabel('Epochs')
  ax2.set_ylabel('Accuracy')
  #ax2.set_xlim(-0.5,10)
  #ax2.set_ylim(0.5,0.9)
  fig.savefig(f'model_v6/plot_{i}')
  fig.show()

# %%
# ROC Curve and AUC value with error
import sklearn.metrics as metrics
from keras import models

plt.figure()
for i in range(9):
  model=models.load_model(f'model_v6/model_{i+1}.h5')
  # calculate the fpr and tpr for all thresholds of the classification
  probs = model.predict(data_test)
  fpr, tpr, threshold = metrics.roc_curve(l_test, probs)
  roc_auc = metrics.auc(fpr, tpr)

  plt.plot(fpr, tpr, label = f'AUC{i+1} = %0.2f' % roc_auc)
  plt.legend(loc = 'lower right')

plt.title('Receiver Operating Characteristic')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(f'model_v6/plot_auc')
plt.show()
